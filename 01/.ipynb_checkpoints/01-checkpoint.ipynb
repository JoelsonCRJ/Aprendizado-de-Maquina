# %%
# %matplotlib inline
import pandas as pd

# %%
data= pd.read_csv('iris.txt',sep=" ", header = None)

# %%
pd.plotting.scatter_matrix(data.loc[:,0:3],figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a3ad05630>,
# ...
#       dtype=object)
